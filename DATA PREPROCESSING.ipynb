# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path ='/content/Team Bandhilki Crop Yield dataset.csv'
data = pd.read_csv(file_path)

# %%
print(data.head())
# Out:
#   Soil_Type    pH  Organic_Matter(%)  Nitrogen_Content(kg/ha)  \
# 0     Loamy  5.18               3.11                      120
# 1     Loamy  8.50               3.45                      192
# 2     Sandy  7.93               2.59                       52
# 3    Clayey  8.39               2.49                      182
# 4    Clayey  8.24               1.46                       98
#
#    Phosphorus_Content(kg/ha)  Potassium_Content(kg/ha)  Rainfall(mm)  \
# 0                         20                       222           365
# 1                        138                       241           859
# 2                        125                       222          1445
# 3                         33                       117           503
# 4                         68                       199           334
#
#    Temperature(°C) Crop_Type  Yield(kg/ha)
# 0             38.6      Rice       2241.44
# 1             34.2   Soybean       3027.53
# 2             34.1     Maize       1678.00
# 3             22.2     Wheat       1671.30
# 4             18.0   Soybean       2508.23

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Soil_Type                  688 non-null    object
#  1   pH                         688 non-null    float64
#  2   Organic_Matter(%)          688 non-null    float64
#  3   Nitrogen_Content(kg/ha)    688 non-null    int64
#  4   Phosphorus_Content(kg/ha)  688 non-null    int64
#  5   Potassium_Content(kg/ha)   688 non-null    int64
#  6   Rainfall(mm)               688 non-null    int64
#  7   Temperature(°C)            688 non-null    float64
#  8   Crop_Type                  688 non-null    object
#  9   Yield(kg/ha)               688 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 53.9+ KB
# None

# %%
print(data.describe())
# Out:
#                pH  Organic_Matter(%)  Nitrogen_Content(kg/ha)  \
# count  688.000000         688.000000               688.000000
# mean     6.790945           2.802427               128.462209
# std      1.032636           1.272826                44.130431
# min      5.000000           0.510000                50.000000
# 25%      5.870000           1.720000                92.000000
# 50%      6.815000           2.830000               126.500000
# 75%      7.732500           3.880000               170.000000
# max      8.500000           5.000000               200.000000
#
#        Phosphorus_Content(kg/ha)  Potassium_Content(kg/ha)  Rainfall(mm)  \
# count                 688.000000                688.000000    688.000000
# mean                   85.250000                174.693314   1077.187500
# std                    37.377281                 72.056103    524.325947
# min                    20.000000                 50.000000    201.000000
# 25%                    54.000000                110.750000    595.750000
# 50%                    85.000000                173.500000   1082.000000
# 75%                   117.000000                235.000000   1539.250000
# max                   150.000000                300.000000   1997.000000
#
#        Temperature(°C)  Yield(kg/ha)
# count       688.000000    688.000000
# mean         27.599564   2744.777224
# std           7.075049   1292.159321
# min          15.100000    508.800000
# 25%          21.975000   1628.680000
# 50%          27.600000   2788.005000
# 75%          33.425000   3825.237500
# max          40.000000   4998.180000

# %%
print(data.isnull().sum())
# Out:
# Soil_Type                    0
# pH                           0
# Organic_Matter(%)            0
# Nitrogen_Content(kg/ha)      0
# Phosphorus_Content(kg/ha)    0
# Potassium_Content(kg/ha)     0
# Rainfall(mm)                 0
# Temperature(°C)              0
# Crop_Type                    0
# Yield(kg/ha)                 0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
original_count = len(data)
threshold = int(original_count * 0.8)
print(f"Minimum required entries: {threshold}")
print(f"Cleaned dataset entries: {len(data)}")
# Out:
# Minimum required entries: 550
# Cleaned dataset entries: 688

# %%
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
sns.pairplot(data, diag_kind="kde")
plt.show()
# Out:
# This cell output is too large and can only be displayed while logged in.

# %%
categorical_cols = data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data[col])
    plt.title(f"Countplot of {col}")
    plt.show()
